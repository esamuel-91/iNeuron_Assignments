# %%
import pymongo
import logging as lg

logger = lg.getLogger()
logger.setLevel(lg.DEBUG)

## create handlers and formatters

shandler = lg.StreamHandler()
fhandler = lg.FileHandler("mongo_update.log")
sformatter = lg.Formatter("%(levelno)s | %(message)s")
fformatter = lg.Formatter("%(asctime)s | %(levelname)s %(message)s")
shandler.setFormatter(sformatter)
fhandler.setFormatter(fformatter)

## adding handler to logger

logger.addHandler(shandler)
logger.addHandler(fhandler)

class Mongodb:
    
    def __init__(self,host,user,password):
        self.host = host
        self.user = user
        self.password = password
        
    def connect(self):
        '''
        func will connect to the monogo server. 
        '''
        logger.info("Trying to connect to data base")
        try:
            client = pymongo.MongoClient("mongodb+srv://"+self.user+":"+self.password+"@cluster0.uvwhbzu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
            logger.debug("Database conncented")
            return client
        
        except pymongo.errors.PyMongoError as e:
            logger.error(f"Oh! You got an error: {e}")
            
    def insert(self,database,subset_name,data):
        '''
        func will try inseting the data.
        '''
        logger.info("Trying to insert the data")
        try:
            conn = self.connect()
            db = conn[database]
            col = db[subset_name]
            col.insert_one(data)
            logger.debug("Data successfully inserted")
        except pymongo.errors.PyMongoError as e:
            logger.error(f"Oh! You got an error: {e}")
            
    def update(self,database,subset_name,data,new_data):
        '''
        func will update the data.
        '''
        logger.info("Trying to update the data")
        try:
            conn = self.connect()
            db = conn[database]
            col = db[subset_name]
            col.update_one(data,{"$set":new_data})
            logger.debug("Data updated")
        except pymongo.errors.PyMongoError as e:
            logger.error(f"Oh! You got an error: {e}")
            
    
    def delete(self,database,subset_name,data):
        '''
        this func will delete the document. 
        '''
        logger.info("trying to delete the doc")
        try:
            conn = self.connect()
            db = conn[database]
            col = db[subset_name]
            col.delete_one(data)
            logger.debug("This data is deleted ---> ")
        except pymongo.errors.PyMongoError as e:
            logger.error(f"Oh! You got an error: {e}")

# %%
mon = Mongodb("localhost","egglistens911","Snehaes89")

# %%
mon.connect()

# %%
mon.insert("iNeuron","FSDS",{"name": "Sneha Lohia", "age" : 34, "course_name":"Python","course_duration":"6 months"})
# Out:
# 20 | Trying to insert the data
# 20 | Trying to connect to data base
# 10 | Database conncented
# 10 | {"message": "Server selection started", "selector": "<function writable_server_selector at 0x129431260>", "operation": "insert", "topologyDescription": "<TopologyDescription id: 6643687a844b9a091533703f, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-txqwiap-shard-00-00.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-02.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "6643687a844b9a091533703f"}}
# 20 | {"message": "Waiting for suitable server to become available", "selector": "<function writable_server_selector at 0x129431260>", "operation": "insert", "topologyDescription": "<TopologyDescription id: 6643687a844b9a091533703f, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-txqwiap-shard-00-00.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-02.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "6643687a844b9a091533703f"}, "remainingTimeMS": 29}
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Starting new HTTP connection (1): r3.o.lencr.org:80
# 10 | Starting new HTTP connection (1): r3.o.lencr.org:80
# 10 | Starting new HTTP connection (1): r3.o.lencr.org:80
# 10 | http://r3.o.lencr.org:80 "POST / HTTP/1.1" 200 503
# 10 | OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# 10 | http://r3.o.lencr.org:80 "POST / HTTP/1.1" 200 503
# 10 | Verifying response
# 10 | OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# 10 | Responder is issuer
# 10 | Verifying response
# 10 | Caching OCSP response.
# 10 | Responder is issuer
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | http://r3.o.lencr.org:80 "POST / HTTP/1.1" 200 503
# 10 | Caching OCSP response.
# 10 | OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Verifying response
# 10 | Responder is issuer
# 10 | Caching OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | {"message": "Server selection succeeded", "selector": "<function writable_server_selector at 0x129431260>", "operation": "insert", "topologyDescription": "<TopologyDescription id: 6643687a844b9a091533703f, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('ac-txqwiap-shard-00-00.uvwhbzu.mongodb.net', 27017) server_type: RSSecondary, rtt: 0.05010862500057556>, <ServerDescription ('ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net', 27017) server_type: RSPrimary, rtt: 0.0421485839979141>, <ServerDescription ('ac-txqwiap-shard-00-02.uvwhbzu.mongodb.net', 27017) server_type: RSSecondary, rtt: 0.03409641699909116>]>", "clientId": {"$oid": "6643687a844b9a091533703f"}, "serverHost": "ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net", "serverPort": 27017}
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Using cached OCSP response.
# 10 | Peer did not staple an OCSP response
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Using cached OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Using cached OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Using cached OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | {"clientId": {"$oid": "6643687a844b9a091533703f"}, "message": "Command started", "command": "{\"insert\": \"FSDS\", \"ordered\": true, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"aa3G3AS1SgqJBTf5P7JBuw==\", \"subType\": \"04\"}}}, \"txnNumber\": 1, \"$clusterTime\": {\"clusterTime\": {\"$timestamp\": {\"t\": 1715693690, \"i\": 4}}, \"signature\": {\"hash\": {\"$binary\": {\"base64\": \"nYjx964mlEhwVTbTdgWdTx8GaMY=\", \"subType\": \"00\"}}, \"keyId\": 7319900259923001350}}, \"writeConcern\": {\"w\": \"majority\"}, \"$db\": \"iNeuron\", \"documents\": [{\"name\": \"Sneha Lohia\", \"age\": 34, \"course_name\": \"Python\", \"course_duration\": \"6 months\", \"_id\": {\"$oid\": \"6643687a844b9a0915337040\"}}]}", "commandName": "insert", "databaseName": "iNeuron", "requestId": 824938981, "operationId": 824938981, "driverConnectionId": 1, "serverConnectionId": 8151, "serverHost": "ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net", "serverPort": 27017}
# 10 | {"clientId": {"$oid": "6643687a844b9a091533703f"}, "message": "Command succeeded", "durationMS": 35.845, "reply": "{\"n\": 1, \"electionId\": {\"$oid\": \"7fffffff000000000000002a\"}, \"opTime\": {\"ts\": {\"$timestamp\": {\"t\": 1715693690, \"i\": 9}}, \"t\": 42}, \"ok\": 1.0, \"$clusterTime\": {\"clusterTime\": {\"$timestamp\": {\"t\": 1715693690, \"i\": 9}}, \"signature\": {\"hash\": {\"$binary\": {\"base64\": \"nYjx964mlEhwVTbTdgWdTx8GaMY=\", \"subType\": \"00\"}}, \"keyId\": 7319900259923001350}}, \"operationTime\": {\"$timestamp\": {\"t\": 1715693690, \"i\": 9}}}", "commandName": "insert", "databaseName": "iNeuron", "requestId": 824938981, "operationId": 824938981, "driverConnectionId": 1, "serverConnectionId": 8151, "serverHost": "ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net", "serverPort": 27017}
# 10 | Data successfully inserted

# %%
mon.update("iNeuron","FSDS",{"age":34},{"age":35})
# Out:
# 20 | Trying to update the data
# 20 | Trying to connect to data base
# 10 | Database conncented
# 10 | {"message": "Server selection started", "selector": "<function writable_server_selector at 0x129431260>", "operation": "update", "topologyDescription": "<TopologyDescription id: 66436818844b9a091533703d, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-txqwiap-shard-00-00.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-02.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "66436818844b9a091533703d"}}
# 20 | {"message": "Waiting for suitable server to become available", "selector": "<function writable_server_selector at 0x129431260>", "operation": "update", "topologyDescription": "<TopologyDescription id: 66436818844b9a091533703d, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-txqwiap-shard-00-00.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-02.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "66436818844b9a091533703d"}, "remainingTimeMS": 29}
# 10 | Peer did not staple an OCSP response
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Trying http://r3.o.lencr.org
# 10 | Starting new HTTP connection (1): r3.o.lencr.org:80
# 10 | Starting new HTTP connection (1): r3.o.lencr.org:80
# 10 | Starting new HTTP connection (1): r3.o.lencr.org:80
# 10 | http://r3.o.lencr.org:80 "POST / HTTP/1.1" 200 503
# 10 | http://r3.o.lencr.org:80 "POST / HTTP/1.1" 200 503
# 10 | http://r3.o.lencr.org:80 "POST / HTTP/1.1" 200 503
# 10 | OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# 10 | OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# 10 | OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# 10 | Verifying response
# 10 | Responder is issuer
# 10 | Verifying response
# 10 | Verifying response
# 10 | Caching OCSP response.
# 10 | Responder is issuer
# 10 | Responder is issuer
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Caching OCSP response.
# 10 | Caching OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | {"message": "Server selection succeeded", "selector": "<function writable_server_selector at 0x129431260>", "operation": "update", "topologyDescription": "<TopologyDescription id: 66436818844b9a091533703d, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('ac-txqwiap-shard-00-00.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net', 27017) server_type: RSPrimary, rtt: 0.0326232080005866>, <ServerDescription ('ac-txqwiap-shard-00-02.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "66436818844b9a091533703d"}, "serverHost": "ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net", "serverPort": 27017}
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Peer did not staple an OCSP response
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Requesting OCSP data
# 10 | Peer did not staple an OCSP response
# 10 | Trying http://r3.o.lencr.org
# 10 | Using cached OCSP response.
# 10 | Trying http://r3.o.lencr.org
# 10 | Requesting OCSP data
# 10 | Using cached OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Using cached OCSP response.
# 10 | Trying http://r3.o.lencr.org
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Using cached OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | {"clientId": {"$oid": "66436818844b9a091533703d"}, "message": "Command started", "command": "{\"update\": \"FSDS\", \"ordered\": true, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"PERUqcKATmKvl6UkqqDKmQ==\", \"subType\": \"04\"}}}, \"txnNumber\": 1, \"$clusterTime\": {\"clusterTime\": {\"$timestamp\": {\"t\": 1715693592, \"i\": 8}}, \"signature\": {\"hash\": {\"$binary\": {\"base64\": \"2H75sZR3HcLfY9Dq3FSXjh+5xfk=\", \"subType\": \"00\"}}, \"keyId\": 7319900259923001350}}, \"writeConcern\": {\"w\": \"majority\"}, \"$db\": \"iNeuron\", \"updates\": [{\"q\": {\"age\": 34}, \"u\": {\"$set\": {\"age\": 35}}}]}", "commandName": "update", "databaseName": "iNeuron", "requestId": 156091745, "operationId": 156091745, "driverConnectionId": 1, "serverConnectionId": 8109, "serverHost": "ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net", "serverPort": 27017}
# 10 | {"clientId": {"$oid": "66436818844b9a091533703d"}, "message": "Command succeeded", "durationMS": 57.492000000000004, "reply": "{\"n\": 1, \"electionId\": {\"$oid\": \"7fffffff000000000000002a\"}, \"opTime\": {\"ts\": {\"$timestamp\": {\"t\": 1715693593, \"i\": 1}}, \"t\": 42}, \"nModified\": 1, \"ok\": 1.0, \"$clusterTime\": {\"clusterTime\": {\"$timestamp\": {\"t\": 1715693593, \"i\": 1}}, \"signature\": {\"hash\": {\"$binary\": {\"base64\": \"M3CIjTcLdSpFf2D5/PMXET8NuwU=\", \"subType\": \"00\"}}, \"keyId\": 7319900259923001350}}, \"operationTime\": {\"$timestamp\": {\"t\": 1715693593, \"i\": 1}}}", "commandName": "update", "databaseName": "iNeuron", "requestId": 156091745, "operationId": 156091745, "driverConnectionId": 1, "serverConnectionId": 8109, "serverHost": "ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net", "serverPort": 27017}
# 10 | Data updated

# %%
mon.delete("iNeuron","FSDS",{"age":35})
# Out:
# 20 | trying to delete the doc
# 20 | Trying to connect to data base
# 10 | Database conncented
# 10 | {"message": "Server selection started", "selector": "<function writable_server_selector at 0x129431260>", "operation": "delete", "topologyDescription": "<TopologyDescription id: 6643683b844b9a091533703e, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-txqwiap-shard-00-00.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-02.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "6643683b844b9a091533703e"}}
# 20 | {"message": "Waiting for suitable server to become available", "selector": "<function writable_server_selector at 0x129431260>", "operation": "delete", "topologyDescription": "<TopologyDescription id: 6643683b844b9a091533703e, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-txqwiap-shard-00-00.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>, <ServerDescription ('ac-txqwiap-shard-00-02.uvwhbzu.mongodb.net', 27017) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "6643683b844b9a091533703e"}, "remainingTimeMS": 29}
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Starting new HTTP connection (1): r3.o.lencr.org:80
# 10 | Starting new HTTP connection (1): r3.o.lencr.org:80
# 10 | Starting new HTTP connection (1): r3.o.lencr.org:80
# 10 | http://r3.o.lencr.org:80 "POST / HTTP/1.1" 200 503
# 10 | http://r3.o.lencr.org:80 "POST / HTTP/1.1" 200 503
# 10 | http://r3.o.lencr.org:80 "POST / HTTP/1.1" 200 503
# 10 | OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# 10 | OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# 10 | OCSP response status: <OCSPResponseStatus.SUCCESSFUL: 0>
# 10 | Verifying response
# 10 | Verifying response
# 10 | Verifying response
# 10 | Responder is issuer
# 10 | Responder is issuer
# 10 | Responder is issuer
# 10 | Caching OCSP response.
# 10 | Caching OCSP response.
# 10 | Caching OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | {"message": "Server selection succeeded", "selector": "<function writable_server_selector at 0x129431260>", "operation": "delete", "topologyDescription": "<TopologyDescription id: 6643683b844b9a091533703e, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('ac-txqwiap-shard-00-00.uvwhbzu.mongodb.net', 27017) server_type: RSSecondary, rtt: 0.0436415419972036>, <ServerDescription ('ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net', 27017) server_type: RSPrimary, rtt: 0.04512912499922095>, <ServerDescription ('ac-txqwiap-shard-00-02.uvwhbzu.mongodb.net', 27017) server_type: RSSecondary, rtt: 0.03968712499772664>]>", "clientId": {"$oid": "6643683b844b9a091533703e"}, "serverHost": "ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net", "serverPort": 27017}
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Using cached OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Using cached OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Using cached OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | Peer did not staple an OCSP response
# 10 | Requesting OCSP data
# 10 | Trying http://r3.o.lencr.org
# 10 | Using cached OCSP response.
# 10 | OCSP cert status: <OCSPCertStatus.GOOD: 0>
# 10 | {"clientId": {"$oid": "6643683b844b9a091533703e"}, "message": "Command started", "command": "{\"delete\": \"FSDS\", \"ordered\": true, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"+ZwTESm/RsiqUL7h89At0g==\", \"subType\": \"04\"}}}, \"txnNumber\": 1, \"$clusterTime\": {\"clusterTime\": {\"$timestamp\": {\"t\": 1715693628, \"i\": 8}}, \"signature\": {\"hash\": {\"$binary\": {\"base64\": \"fueDppecux3dVCek4NQGMD2V6Rc=\", \"subType\": \"00\"}}, \"keyId\": 7319900259923001350}}, \"writeConcern\": {\"w\": \"majority\"}, \"$db\": \"iNeuron\", \"deletes\": [{\"q\": {\"age\": 35}, \"limit\": 1}]}", "commandName": "delete", "databaseName": "iNeuron", "requestId": 1952509530, "operationId": 1952509530, "driverConnectionId": 1, "serverConnectionId": 8138, "serverHost": "ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net", "serverPort": 27017}
# 10 | {"clientId": {"$oid": "6643683b844b9a091533703e"}, "message": "Command succeeded", "durationMS": 41.482, "reply": "{\"n\": 1, \"electionId\": {\"$oid\": \"7fffffff000000000000002a\"}, \"opTime\": {\"ts\": {\"$timestamp\": {\"t\": 1715693628, \"i\": 9}}, \"t\": 42}, \"ok\": 1.0, \"$clusterTime\": {\"clusterTime\": {\"$timestamp\": {\"t\": 1715693628, \"i\": 9}}, \"signature\": {\"hash\": {\"$binary\": {\"base64\": \"fueDppecux3dVCek4NQGMD2V6Rc=\", \"subType\": \"00\"}}, \"keyId\": 7319900259923001350}}, \"operationTime\": {\"$timestamp\": {\"t\": 1715693628, \"i\": 9}}}", "commandName": "delete", "databaseName": "iNeuron", "requestId": 1952509530, "operationId": 1952509530, "driverConnectionId": 1, "serverConnectionId": 8138, "serverHost": "ac-txqwiap-shard-00-01.uvwhbzu.mongodb.net", "serverPort": 27017}
# 10 | This data is deleted --->
